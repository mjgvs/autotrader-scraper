# %% [markdown]
# # autotrader scraper
#
# In this notebook, i'll be testing out the code provided in this blog post: https://www.shedloadofcode.com/blog/building-an-autotrader-scraper-with-python-to-search-for-multiple-makes-and-models
#
# *make sure you are on the `webscraper` virtual environment!`

# %%
# !python -m pip install numpy pandas requests cloudscraper bs4 xlsxwriter openpyxl

# %%
# !python autotrader-searcher.py

# %%
from autotrader_scraper import get_cars
import pandas as pd

# %%
criteria = {
    "postcode": "LS6 3DT", 
    "min_year": 2020,
    "max_year": 2023,
    "radius": 1000,
    "min_price": 0,
    "max_price": 100000,
    "fuel": "Hybrid – Petrol/Electric",
    "transmission": "Automatic",
    "max_mileage": 1000000,
    "max_attempts_per_page": 1,
    "verbose": True
}

# %%
prius = get_cars(
    make = "Toyota",
    model = "Prius",
    postcode = criteria["postcode"],
    radius = criteria["radius"],
    min_year = criteria["min_year"],
    max_year = criteria["max_year"],
    include_writeoff = "exclude",
    max_attempts_per_page = criteria["max_attempts_per_page"],
    verbose = criteria["verbose"]
)

print("Prius search done.")
# Out:
# Year:  2020,      Page:  1,      Response:  <Response [200]>
# Year:  2020,      Page:  2,      Response:  <Response [200]>
# Year:  2020,      Page:  3,      Response:  <Response [200]>
# Year:  2020,      Page:  4,      Response:  <Response [200]>
# Year:  2020,      Page:  5,      Response:  <Response [200]>
# Found total 33 results for year 2020 across 4 pages
# Moving on to year 2021
# ---------------------------------
# Year:  2021,      Page:  1,      Response:  <Response [200]>
# Year:  2021,      Page:  2,      Response:  <Response [200]>
# Year:  2021,      Page:  3,      Response:  <Response [200]>
# Found total 13 results for year 2021 across 2 pages
# Moving on to year 2022
# ---------------------------------
# Year:  2022,      Page:  1,      Response:  <Response [200]>
# Year:  2022,      Page:  2,      Response:  <Response [200]>
# Found total 10 results for year 2022 across 1 pages
# Moving on to year 2023
# ---------------------------------
# Year:  2023,      Page:  1,      Response:  <Response [200]>
# Year:  2023,      Page:  2,      Response:  <Response [200]>
# Found total 9 results for year 2023 across 1 pages
# Prius search done.

# %%
corolla = get_cars(
    make = "Toyota",
    model = "Corolla",
    postcode = criteria["postcode"],
    radius = criteria["radius"],
    min_year = criteria["min_year"], # exception as there are no 2015 corollas, they start at 2019, and then the script runs forever on non-existent pages...
    max_year = criteria["max_year"],
    include_writeoff = "exclude",
    max_attempts_per_page = criteria["max_attempts_per_page"],
    verbose = criteria["verbose"]
)

print("Corolla search done.")
# Out:
# Year:  2020,      Page:  1,      Response:  <Response [200]>
# Year:  2020,      Page:  2,      Response:  <Response [200]>
# Year:  2020,      Page:  3,      Response:  <Response [200]>
# Year:  2020,      Page:  4,      Response:  <Response [200]>
# Year:  2020,      Page:  5,      Response:  <Response [200]>
# Year:  2020,      Page:  6,      Response:  <Response [200]>
# Year:  2020,      Page:  7,      Response:  <Response [200]>
# Year:  2020,      Page:  8,      Response:  <Response [200]>
# Year:  2020,      Page:  9,      Response:  <Response [200]>
# Year:  2020,      Page:  10,      Response:  <Response [200]>
# Year:  2020,      Page:  11,      Response:  <Response [200]>
# Year:  2020,      Page:  12,      Response:  <Response [200]>
# Year:  2020,      Page:  13,      Response:  <Response [200]>
# Year:  2020,      Page:  14,      Response:  <Response [200]>
# Year:  2020,      Page:  15,      Response:  <Response [200]>
# Year:  2020,      Page:  16,      Response:  <Response [200]>
# Year:  2020,      Page:  17,      Response:  <Response [200]>
# Year:  2020,      Page:  18,      Response:  <Response [200]>
# Year:  2020,      Page:  19,      Response:  <Response [200]>
# Year:  2020,      Page:  20,      Response:  <Response [200]>
# Year:  2020,      Page:  21,      Response:  <Response [200]>
# Year:  2020,      Page:  22,      Response:  <Response [200]>
# Year:  2020,      Page:  23,      Response:  <Response [200]>
# Year:  2020,      Page:  24,      Response:  <Response [200]>
# Year:  2020,      Page:  25,      Response:  <Response [200]>
# Year:  2020,      Page:  26,      Response:  <Response [200]>
# Year:  2020,      Page:  27,      Response:  <Response [200]>
# Year:  2020,      Page:  28,      Response:  <Response [200]>
# Year:  2020,      Page:  29,      Response:  <Response [200]>
# Year:  2020,      Page:  30,      Response:  <Response [200]>
# Year:  2020,      Page:  31,      Response:  <Response [200]>
# Year:  2020,      Page:  32,      Response:  <Response [200]>
# Year:  2020,      Page:  33,      Response:  <Response [200]>
# Year:  2020,      Page:  34,      Response:  <Response [200]>
# Year:  2020,      Page:  35,      Response:  <Response [200]>
# Year:  2020,      Page:  36,      Response:  <Response [200]>
# Year:  2020,      Page:  37,      Response:  <Response [200]>
# Year:  2020,      Page:  38,      Response:  <Response [200]>
# Year:  2020,      Page:  39,      Response:  <Response [200]>
# Year:  2020,      Page:  40,      Response:  <Response [200]>
# Year:  2020,      Page:  41,      Response:  <Response [200]>
# Year:  2020,      Page:  42,      Response:  <Response [200]>
# Year:  2020,      Page:  43,      Response:  <Response [200]>
# Year:  2020,      Page:  44,      Response:  <Response [200]>
# Year:  2020,      Page:  45,      Response:  <Response [200]>
# Year:  2020,      Page:  46,      Response:  <Response [200]>
# Year:  2020,      Page:  47,      Response:  <Response [200]>
# Year:  2020,      Page:  48,      Response:  <Response [200]>
# Year:  2020,      Page:  49,      Response:  <Response [200]>
# Year:  2020,      Page:  50,      Response:  <Response [200]>
# Found total 488 results for year 2020 across 49 pages
# Moving on to year 2021
# ---------------------------------
# Year:  2021,      Page:  1,      Response:  <Response [200]>
# Year:  2021,      Page:  2,      Response:  <Response [200]>
# Year:  2021,      Page:  3,      Response:  <Response [200]>
# Year:  2021,      Page:  4,      Response:  <Response [200]>
# Year:  2021,      Page:  5,      Response:  <Response [200]>
# Year:  2021,      Page:  6,      Response:  <Response [200]>
# Year:  2021,      Page:  7,      Response:  <Response [200]>
# Year:  2021,      Page:  8,      Response:  <Response [200]>
# Year:  2021,      Page:  9,      Response:  <Response [200]>
# Year:  2021,      Page:  10,      Response:  <Response [200]>
# Year:  2021,      Page:  11,      Response:  <Response [200]>
# Year:  2021,      Page:  12,      Response:  <Response [200]>
# Year:  2021,      Page:  13,      Response:  <Response [200]>
# Year:  2021,      Page:  14,      Response:  <Response [200]>
# Year:  2021,      Page:  15,      Response:  <Response [200]>
# Year:  2021,      Page:  16,      Response:  <Response [200]>
# Year:  2021,      Page:  17,      Response:  <Response [200]>
# Year:  2021,      Page:  18,      Response:  <Response [200]>
# Year:  2021,      Page:  19,      Response:  <Response [200]>
# Year:  2021,      Page:  20,      Response:  <Response [200]>
# Year:  2021,      Page:  21,      Response:  <Response [200]>
# Year:  2021,      Page:  22,      Response:  <Response [200]>
# Year:  2021,      Page:  23,      Response:  <Response [200]>
# Found total 220 results for year 2021 across 22 pages
# Moving on to year 2022
# ---------------------------------
# Year:  2022,      Page:  1,      Response:  <Response [200]>
# Year:  2022,      Page:  2,      Response:  <Response [200]>
# Year:  2022,      Page:  3,      Response:  <Response [200]>
# Year:  2022,      Page:  4,      Response:  <Response [200]>
# Year:  2022,      Page:  5,      Response:  <Response [200]>
# Year:  2022,      Page:  6,      Response:  <Response [200]>
# Year:  2022,      Page:  7,      Response:  <Response [200]>
# Year:  2022,      Page:  8,      Response:  <Response [200]>
# Year:  2022,      Page:  9,      Response:  <Response [200]>
# Year:  2022,      Page:  10,      Response:  <Response [200]>
# Year:  2022,      Page:  11,      Response:  <Response [200]>
# Year:  2022,      Page:  12,      Response:  <Response [200]>
# Year:  2022,      Page:  13,      Response:  <Response [200]>
# Year:  2022,      Page:  14,      Response:  <Response [200]>
# Year:  2022,      Page:  15,      Response:  <Response [200]>
# Year:  2022,      Page:  16,      Response:  <Response [200]>
# Year:  2022,      Page:  17,      Response:  <Response [200]>
# Year:  2022,      Page:  18,      Response:  <Response [200]>
# Year:  2022,      Page:  19,      Response:  <Response [200]>
# Year:  2022,      Page:  20,      Response:  <Response [200]>
# Year:  2022,      Page:  21,      Response:  <Response [200]>
# Year:  2022,      Page:  22,      Response:  <Response [200]>
# Found total 201 results for year 2022 across 21 pages
# Moving on to year 2023
# ---------------------------------
# Year:  2023,      Page:  1,      Response:  <Response [200]>
# Year:  2023,      Page:  2,      Response:  <Response [200]>
# Year:  2023,      Page:  3,      Response:  <Response [200]>
# Found total 13 results for year 2023 across 2 pages
# Corolla search done.

# %%
ioniq = get_cars(
    make = "Hyundai",
    model = "Ioniq",
    postcode = criteria["postcode"],
    radius = criteria["radius"],
    min_year = criteria["min_year"],
    max_year = criteria["max_year"],
    include_writeoff = "exclude",
    max_attempts_per_page = criteria["max_attempts_per_page"],
    verbose = criteria["verbose"]
)

print("Ioniq search done.")
# Out:
# Year:  2020,      Page:  1,      Response:  <Response [200]>
# Year:  2020,      Page:  2,      Response:  <Response [200]>
# Year:  2020,      Page:  3,      Response:  <Response [200]>
# Year:  2020,      Page:  4,      Response:  <Response [200]>
# Year:  2020,      Page:  5,      Response:  <Response [200]>
# Year:  2020,      Page:  6,      Response:  <Response [200]>
# Year:  2020,      Page:  7,      Response:  <Response [200]>
# Year:  2020,      Page:  8,      Response:  <Response [200]>
# Year:  2020,      Page:  9,      Response:  <Response [200]>
# Year:  2020,      Page:  10,      Response:  <Response [200]>
# Year:  2020,      Page:  11,      Response:  <Response [200]>
# Year:  2020,      Page:  12,      Response:  <Response [200]>
# Year:  2020,      Page:  13,      Response:  <Response [200]>
# Year:  2020,      Page:  14,      Response:  <Response [200]>
# Year:  2020,      Page:  15,      Response:  <Response [200]>
# Year:  2020,      Page:  16,      Response:  <Response [200]>
# Year:  2020,      Page:  17,      Response:  <Response [200]>
# Year:  2020,      Page:  18,      Response:  <Response [200]>
# Year:  2020,      Page:  19,      Response:  <Response [200]>
# Year:  2020,      Page:  20,      Response:  <Response [200]>
# Year:  2020,      Page:  21,      Response:  <Response [200]>
# Year:  2020,      Page:  22,      Response:  <Response [200]>
# Year:  2020,      Page:  23,      Response:  <Response [200]>
# Year:  2020,      Page:  24,      Response:  <Response [200]>
# Year:  2020,      Page:  25,      Response:  <Response [200]>
# Year:  2020,      Page:  26,      Response:  <Response [200]>
# Year:  2020,      Page:  27,      Response:  <Response [200]>
# Year:  2020,      Page:  28,      Response:  <Response [200]>
# Found total 269 results for year 2020 across 27 pages
# Moving on to year 2021
# ---------------------------------
# Year:  2021,      Page:  1,      Response:  <Response [200]>
# Year:  2021,      Page:  2,      Response:  <Response [200]>
# Year:  2021,      Page:  3,      Response:  <Response [200]>
# Year:  2021,      Page:  4,      Response:  <Response [200]>
# Year:  2021,      Page:  5,      Response:  <Response [200]>
# Year:  2021,      Page:  6,      Response:  <Response [200]>
# Year:  2021,      Page:  7,      Response:  <Response [200]>
# Year:  2021,      Page:  8,      Response:  <Response [200]>
# Year:  2021,      Page:  9,      Response:  <Response [200]>
# Year:  2021,      Page:  10,      Response:  <Response [200]>
# Year:  2021,      Page:  11,      Response:  <Response [200]>
# Year:  2021,      Page:  12,      Response:  <Response [200]>
# Year:  2021,      Page:  13,      Response:  <Response [200]>
# Year:  2021,      Page:  14,      Response:  <Response [200]>
# Year:  2021,      Page:  15,      Response:  <Response [200]>
# Year:  2021,      Page:  16,      Response:  <Response [200]>
# Year:  2021,      Page:  17,      Response:  <Response [200]>
# Found total 159 results for year 2021 across 16 pages
# Moving on to year 2022
# ---------------------------------
# Year:  2022,      Page:  1,      Response:  <Response [200]>
# Year:  2022,      Page:  2,      Response:  <Response [200]>
# Year:  2022,      Page:  3,      Response:  <Response [200]>
# Year:  2022,      Page:  4,      Response:  <Response [200]>
# Year:  2022,      Page:  5,      Response:  <Response [200]>
# Year:  2022,      Page:  6,      Response:  <Response [200]>
# Year:  2022,      Page:  7,      Response:  <Response [200]>
# Year:  2022,      Page:  8,      Response:  <Response [200]>
# Year:  2022,      Page:  9,      Response:  <Response [200]>
# Year:  2022,      Page:  10,      Response:  <Response [200]>
# Found total 87 results for year 2022 across 9 pages
# Moving on to year 2023
# ---------------------------------
# Year:  2023,      Page:  1,      Response:  <Response [200]>
# Year:  2023,      Page:  2,      Response:  <Response [200]>
# Found total 3 results for year 2023 across 1 pages
# Ioniq search done.

# %%
ioniq_5 = get_cars(
    make = "Hyundai",
    model = "Ioniq 5",
    postcode = criteria["postcode"],
    radius = criteria["radius"],
    min_year = criteria["min_year"],
    max_year = criteria["max_year"],
    include_writeoff = "exclude",
    max_attempts_per_page = criteria["max_attempts_per_page"],
    verbose = criteria["verbose"]
)

print("Ioniq 5 search done.")
# Out:
# Year:  2020,      Page:  1,      Response:  <Response [200]>
# Found total 0 results for year 2020 across 0 pages
# Moving on to year 2021
# ---------------------------------
# Year:  2021,      Page:  1,      Response:  <Response [200]>
# Year:  2021,      Page:  2,      Response:  <Response [200]>
# Year:  2021,      Page:  3,      Response:  <Response [200]>
# Year:  2021,      Page:  4,      Response:  <Response [200]>
# Year:  2021,      Page:  5,      Response:  <Response [200]>
# Year:  2021,      Page:  6,      Response:  <Response [200]>
# Found total 44 results for year 2021 across 5 pages
# Moving on to year 2022
# ---------------------------------
# Year:  2022,      Page:  1,      Response:  <Response [200]>
# Year:  2022,      Page:  2,      Response:  <Response [200]>
# Year:  2022,      Page:  3,      Response:  <Response [200]>
# Year:  2022,      Page:  4,      Response:  <Response [200]>
# Year:  2022,      Page:  5,      Response:  <Response [200]>
# Year:  2022,      Page:  6,      Response:  <Response [200]>
# Year:  2022,      Page:  7,      Response:  <Response [200]>
# Year:  2022,      Page:  8,      Response:  <Response [200]>
# Year:  2022,      Page:  9,      Response:  <Response [200]>
# Year:  2022,      Page:  10,      Response:  <Response [200]>
# Year:  2022,      Page:  11,      Response:  <Response [200]>
# Found total 98 results for year 2022 across 10 pages
# Moving on to year 2023
# ---------------------------------
# Year:  2023,      Page:  1,      Response:  <Response [200]>
# Year:  2023,      Page:  2,      Response:  <Response [200]>
# Year:  2023,      Page:  3,      Response:  <Response [200]>
# Found total 13 results for year 2023 across 2 pages
# Ioniq 5 search done.

# %%
civic = get_cars(
    make = "Honda",
    model = "Civic",
    postcode = criteria["postcode"],
    radius = criteria["radius"],
    min_year = criteria["min_year"],
    max_year = criteria["max_year"],
    include_writeoff = "exclude",
    max_attempts_per_page = criteria["max_attempts_per_page"],
    verbose = criteria["verbose"]
)

print("Civic search done.")
# Out:
# Year:  2020,      Page:  1,      Response:  <Response [200]>
# Year:  2020,      Page:  2,      Response:  <Response [200]>
# Year:  2020,      Page:  3,      Response:  <Response [200]>
# Year:  2020,      Page:  4,      Response:  <Response [200]>
# Year:  2020,      Page:  5,      Response:  <Response [200]>
# Year:  2020,      Page:  6,      Response:  <Response [200]>
# Year:  2020,      Page:  7,      Response:  <Response [200]>
# Year:  2020,      Page:  8,      Response:  <Response [200]>
# Year:  2020,      Page:  9,      Response:  <Response [200]>
# Year:  2020,      Page:  10,      Response:  <Response [200]>
# Year:  2020,      Page:  11,      Response:  <Response [200]>
# Year:  2020,      Page:  12,      Response:  <Response [200]>
# Found total 105 results for year 2020 across 11 pages
# Moving on to year 2021
# ---------------------------------
# Year:  2021,      Page:  1,      Response:  <Response [200]>
# Year:  2021,      Page:  2,      Response:  <Response [200]>
# Year:  2021,      Page:  3,      Response:  <Response [200]>
# Year:  2021,      Page:  4,      Response:  <Response [200]>
# Year:  2021,      Page:  5,      Response:  <Response [200]>
# Year:  2021,      Page:  6,      Response:  <Response [200]>
# Year:  2021,      Page:  7,      Response:  <Response [200]>
# Found total 54 results for year 2021 across 6 pages
# Moving on to year 2022
# ---------------------------------
# Year:  2022,      Page:  1,      Response:  <Response [200]>
# Year:  2022,      Page:  2,      Response:  <Response [200]>
# Year:  2022,      Page:  3,      Response:  <Response [200]>
# Year:  2022,      Page:  4,      Response:  <Response [200]>
# Found total 25 results for year 2022 across 3 pages
# Moving on to year 2023
# ---------------------------------
# Year:  2023,      Page:  1,      Response:  <Response [200]>
# Year:  2023,      Page:  2,      Response:  <Response [200]>
# Year:  2023,      Page:  3,      Response:  <Response [200]>
# Year:  2023,      Page:  4,      Response:  <Response [200]>
# Found total 22 results for year 2023 across 3 pages
# Civic search done.

# %%
niro = get_cars(
    make = "Kia",
    model = "Niro",
    postcode = criteria["postcode"],
    radius = criteria["radius"],
    min_year = criteria["min_year"],
    max_year = criteria["max_year"],
    include_writeoff = "exclude",
    max_attempts_per_page = criteria["max_attempts_per_page"],
    verbose = criteria["verbose"]
)

print("Niro search done.")
# Out:
# Year:  2020,      Page:  1,      Response:  <Response [200]>
# Year:  2020,      Page:  2,      Response:  <Response [200]>
# Year:  2020,      Page:  3,      Response:  <Response [200]>
# Year:  2020,      Page:  4,      Response:  <Response [200]>
# Year:  2020,      Page:  5,      Response:  <Response [200]>
# Year:  2020,      Page:  6,      Response:  <Response [200]>
# Year:  2020,      Page:  7,      Response:  <Response [200]>
# Year:  2020,      Page:  8,      Response:  <Response [200]>
# Year:  2020,      Page:  9,      Response:  <Response [200]>
# Year:  2020,      Page:  10,      Response:  <Response [200]>
# Year:  2020,      Page:  11,      Response:  <Response [200]>
# Year:  2020,      Page:  12,      Response:  <Response [200]>
# Year:  2020,      Page:  13,      Response:  <Response [200]>
# Year:  2020,      Page:  14,      Response:  <Response [200]>
# Year:  2020,      Page:  15,      Response:  <Response [200]>
# Year:  2020,      Page:  16,      Response:  <Response [200]>
# Year:  2020,      Page:  17,      Response:  <Response [200]>
# Year:  2020,      Page:  18,      Response:  <Response [200]>
# Year:  2020,      Page:  19,      Response:  <Response [200]>
# Year:  2020,      Page:  20,      Response:  <Response [200]>
# Year:  2020,      Page:  21,      Response:  <Response [200]>
# Year:  2020,      Page:  22,      Response:  <Response [200]>
# Year:  2020,      Page:  23,      Response:  <Response [200]>
# Year:  2020,      Page:  24,      Response:  <Response [200]>
# Year:  2020,      Page:  25,      Response:  <Response [200]>
# Year:  2020,      Page:  26,      Response:  <Response [200]>
# Year:  2020,      Page:  27,      Response:  <Response [200]>
# Year:  2020,      Page:  28,      Response:  <Response [200]>
# Year:  2020,      Page:  29,      Response:  <Response [200]>
# Year:  2020,      Page:  30,      Response:  <Response [200]>
# Year:  2020,      Page:  31,      Response:  <Response [200]>
# Year:  2020,      Page:  32,      Response:  <Response [200]>
# Year:  2020,      Page:  33,      Response:  <Response [200]>
# Year:  2020,      Page:  34,      Response:  <Response [200]>
# Year:  2020,      Page:  35,      Response:  <Response [200]>
# Year:  2020,      Page:  36,      Response:  <Response [200]>
# Year:  2020,      Page:  37,      Response:  <Response [200]>
# Found total 359 results for year 2020 across 36 pages
# Moving on to year 2021
# ---------------------------------
# Year:  2021,      Page:  1,      Response:  <Response [200]>
# Year:  2021,      Page:  2,      Response:  <Response [200]>
# Year:  2021,      Page:  3,      Response:  <Response [200]>
# Year:  2021,      Page:  4,      Response:  <Response [200]>
# Year:  2021,      Page:  5,      Response:  <Response [200]>
# Year:  2021,      Page:  6,      Response:  <Response [200]>
# Year:  2021,      Page:  7,      Response:  <Response [200]>
# Year:  2021,      Page:  8,      Response:  <Response [200]>
# Year:  2021,      Page:  9,      Response:  <Response [200]>
# Year:  2021,      Page:  10,      Response:  <Response [200]>
# Year:  2021,      Page:  11,      Response:  <Response [200]>
# Year:  2021,      Page:  12,      Response:  <Response [200]>
# Year:  2021,      Page:  13,      Response:  <Response [200]>
# Year:  2021,      Page:  14,      Response:  <Response [200]>
# Year:  2021,      Page:  15,      Response:  <Response [200]>
# Year:  2021,      Page:  16,      Response:  <Response [200]>
# Year:  2021,      Page:  17,      Response:  <Response [200]>
# Year:  2021,      Page:  18,      Response:  <Response [200]>
# Year:  2021,      Page:  19,      Response:  <Response [200]>
# Year:  2021,      Page:  20,      Response:  <Response [200]>
# Year:  2021,      Page:  21,      Response:  <Response [200]>
# Year:  2021,      Page:  22,      Response:  <Response [200]>
# Year:  2021,      Page:  23,      Response:  <Response [200]>
# Year:  2021,      Page:  24,      Response:  <Response [200]>
# Year:  2021,      Page:  25,      Response:  <Response [200]>
# Found total 231 results for year 2021 across 24 pages
# Moving on to year 2022
# ---------------------------------
# Year:  2022,      Page:  1,      Response:  <Response [200]>
# Year:  2022,      Page:  2,      Response:  <Response [200]>
# Year:  2022,      Page:  3,      Response:  <Response [200]>
# Year:  2022,      Page:  4,      Response:  <Response [200]>
# Year:  2022,      Page:  5,      Response:  <Response [200]>
# Year:  2022,      Page:  6,      Response:  <Response [200]>
# Year:  2022,      Page:  7,      Response:  <Response [200]>
# Year:  2022,      Page:  8,      Response:  <Response [200]>
# Year:  2022,      Page:  9,      Response:  <Response [200]>
# Year:  2022,      Page:  10,      Response:  <Response [200]>
# Year:  2022,      Page:  11,      Response:  <Response [200]>
# Year:  2022,      Page:  12,      Response:  <Response [200]>
# Year:  2022,      Page:  13,      Response:  <Response [200]>
# Year:  2022,      Page:  14,      Response:  <Response [200]>
# Year:  2022,      Page:  15,      Response:  <Response [200]>
# Year:  2022,      Page:  16,      Response:  <Response [200]>
# Year:  2022,      Page:  17,      Response:  <Response [200]>
# Year:  2022,      Page:  18,      Response:  <Response [200]>
# Year:  2022,      Page:  19,      Response:  <Response [200]>
# Year:  2022,      Page:  20,      Response:  <Response [200]>
# Year:  2022,      Page:  21,      Response:  <Response [200]>
# Year:  2022,      Page:  22,      Response:  <Response [200]>
# Year:  2022,      Page:  23,      Response:  <Response [200]>
# Year:  2022,      Page:  24,      Response:  <Response [200]>
# Year:  2022,      Page:  25,      Response:  <Response [200]>
# Year:  2022,      Page:  26,      Response:  <Response [200]>
# Year:  2022,      Page:  27,      Response:  <Response [200]>
# Year:  2022,      Page:  28,      Response:  <Response [200]>
# Year:  2022,      Page:  29,      Response:  <Response [200]>
# Year:  2022,      Page:  30,      Response:  <Response [200]>
# Year:  2022,      Page:  31,      Response:  <Response [200]>
# Year:  2022,      Page:  32,      Response:  <Response [200]>
# Found total 305 results for year 2022 across 31 pages
# Moving on to year 2023
# ---------------------------------
# Year:  2023,      Page:  1,      Response:  <Response [200]>
# Year:  2023,      Page:  2,      Response:  <Response [200]>
# Year:  2023,      Page:  3,      Response:  <Response [200]>
# Year:  2023,      Page:  4,      Response:  <Response [200]>
# Found total 26 results for year 2023 across 3 pages
# Niro search done.

# %%
EV6 = get_cars(
    make = "Kia",
    model = "EV6",
    postcode = criteria["postcode"],
    radius = criteria["radius"],
    min_year = criteria["min_year"],
    max_year = criteria["max_year"],
    include_writeoff = "exclude",
    max_attempts_per_page = criteria["max_attempts_per_page"],
    verbose = criteria["verbose"]
)

print("EV6 search done.")
# Out:
# Year:  2020,      Page:  1,      Response:  <Response [200]>
# Found total 0 results for year 2020 across 0 pages
# Moving on to year 2021
# ---------------------------------
# Year:  2021,      Page:  1,      Response:  <Response [200]>
# Year:  2021,      Page:  2,      Response:  <Response [200]>
# Year:  2021,      Page:  3,      Response:  <Response [200]>
# Year:  2021,      Page:  4,      Response:  <Response [200]>
# Year:  2021,      Page:  5,      Response:  <Response [200]>
# Found total 33 results for year 2021 across 4 pages
# Moving on to year 2022
# ---------------------------------
# Year:  2022,      Page:  1,      Response:  <Response [200]>
# Year:  2022,      Page:  2,      Response:  <Response [200]>
# Year:  2022,      Page:  3,      Response:  <Response [200]>
# Year:  2022,      Page:  4,      Response:  <Response [200]>
# Year:  2022,      Page:  5,      Response:  <Response [200]>
# Year:  2022,      Page:  6,      Response:  <Response [200]>
# Year:  2022,      Page:  7,      Response:  <Response [200]>
# Year:  2022,      Page:  8,      Response:  <Response [200]>
# Year:  2022,      Page:  9,      Response:  <Response [200]>
# Year:  2022,      Page:  10,      Response:  <Response [200]>
# Found total 85 results for year 2022 across 9 pages
# Moving on to year 2023
# ---------------------------------
# Year:  2023,      Page:  1,      Response:  <Response [200]>
# Year:  2023,      Page:  2,      Response:  <Response [200]>
# Year:  2023,      Page:  3,      Response:  <Response [200]>
# Year:  2023,      Page:  4,      Response:  <Response [200]>
# Year:  2023,      Page:  5,      Response:  <Response [200]>
# Year:  2023,      Page:  6,      Response:  <Response [200]>
# Year:  2023,      Page:  7,      Response:  <Response [200]>
# Found total 55 results for year 2023 across 6 pages
# EV6 search done.

# %%
XC40 = get_cars(
    make = "Volvo",
    model = "XC40",
    postcode = criteria["postcode"],
    radius = criteria["radius"],
    min_year = criteria["min_year"],
    max_year = criteria["max_year"],
    include_writeoff = "exclude",
    max_attempts_per_page = criteria["max_attempts_per_page"],
    verbose = criteria["verbose"]
)

print("XC40 search done.")
# Out:
# Year:  2020,      Page:  1,      Response:  <Response [200]>
# Year:  2020,      Page:  2,      Response:  <Response [200]>
# Year:  2020,      Page:  3,      Response:  <Response [200]>
# Year:  2020,      Page:  4,      Response:  <Response [200]>
# Year:  2020,      Page:  5,      Response:  <Response [200]>
# Year:  2020,      Page:  6,      Response:  <Response [200]>
# Year:  2020,      Page:  7,      Response:  <Response [200]>
# Year:  2020,      Page:  8,      Response:  <Response [200]>
# Year:  2020,      Page:  9,      Response:  <Response [200]>
# Year:  2020,      Page:  10,      Response:  <Response [200]>
# Year:  2020,      Page:  11,      Response:  <Response [200]>
# Year:  2020,      Page:  12,      Response:  <Response [200]>
# Year:  2020,      Page:  13,      Response:  <Response [200]>
# Year:  2020,      Page:  14,      Response:  <Response [200]>
# Year:  2020,      Page:  15,      Response:  <Response [200]>
# Year:  2020,      Page:  16,      Response:  <Response [200]>
# Year:  2020,      Page:  17,      Response:  <Response [200]>
# Year:  2020,      Page:  18,      Response:  <Response [200]>
# Year:  2020,      Page:  19,      Response:  <Response [200]>
# Year:  2020,      Page:  20,      Response:  <Response [200]>
# Year:  2020,      Page:  21,      Response:  <Response [200]>
# Year:  2020,      Page:  22,      Response:  <Response [200]>
# Year:  2020,      Page:  23,      Response:  <Response [200]>
# Year:  2020,      Page:  24,      Response:  <Response [200]>
# Year:  2020,      Page:  25,      Response:  <Response [200]>
# Year:  2020,      Page:  26,      Response:  <Response [200]>
# Year:  2020,      Page:  27,      Response:  <Response [200]>
# Year:  2020,      Page:  28,      Response:  <Response [200]>
# Year:  2020,      Page:  29,      Response:  <Response [200]>
# Year:  2020,      Page:  30,      Response:  <Response [200]>
# Year:  2020,      Page:  31,      Response:  <Response [200]>
# Year:  2020,      Page:  32,      Response:  <Response [200]>
# Year:  2020,      Page:  33,      Response:  <Response [200]>
# Year:  2020,      Page:  34,      Response:  <Response [200]>
# Year:  2020,      Page:  35,      Response:  <Response [200]>
# Year:  2020,      Page:  36,      Response:  <Response [200]>
# Year:  2020,      Page:  37,      Response:  <Response [200]>
# Year:  2020,      Page:  38,      Response:  <Response [200]>
# Year:  2020,      Page:  39,      Response:  <Response [200]>
# Year:  2020,      Page:  40,      Response:  <Response [200]>
# Year:  2020,      Page:  41,      Response:  <Response [200]>
# Year:  2020,      Page:  42,      Response:  <Response [200]>
# Year:  2020,      Page:  43,      Response:  <Response [200]>
# Year:  2020,      Page:  44,      Response:  <Response [200]>
# Year:  2020,      Page:  45,      Response:  <Response [200]>
# Found total 436 results for year 2020 across 44 pages
# Moving on to year 2021
# ---------------------------------
# Year:  2021,      Page:  1,      Response:  <Response [200]>
# Year:  2021,      Page:  2,      Response:  <Response [200]>
# Year:  2021,      Page:  3,      Response:  <Response [200]>
# Year:  2021,      Page:  4,      Response:  <Response [200]>
# Year:  2021,      Page:  5,      Response:  <Response [200]>
# Year:  2021,      Page:  6,      Response:  <Response [200]>
# Year:  2021,      Page:  7,      Response:  <Response [200]>
# Year:  2021,      Page:  8,      Response:  <Response [200]>
# Year:  2021,      Page:  9,      Response:  <Response [200]>
# Year:  2021,      Page:  10,      Response:  <Response [200]>
# Year:  2021,      Page:  11,      Response:  <Response [200]>
# Year:  2021,      Page:  12,      Response:  <Response [200]>
# Year:  2021,      Page:  13,      Response:  <Response [200]>
# Year:  2021,      Page:  14,      Response:  <Response [200]>
# Year:  2021,      Page:  15,      Response:  <Response [200]>
# Year:  2021,      Page:  16,      Response:  <Response [200]>
# Year:  2021,      Page:  17,      Response:  <Response [200]>
# Year:  2021,      Page:  18,      Response:  <Response [200]>
# Year:  2021,      Page:  19,      Response:  <Response [200]>
# Year:  2021,      Page:  20,      Response:  <Response [200]>
# Year:  2021,      Page:  21,      Response:  <Response [200]>
# Year:  2021,      Page:  22,      Response:  <Response [200]>
# Year:  2021,      Page:  23,      Response:  <Response [200]>
# Year:  2021,      Page:  24,      Response:  <Response [200]>
# Year:  2021,      Page:  25,      Response:  <Response [200]>
# Year:  2021,      Page:  26,      Response:  <Response [200]>
# Year:  2021,      Page:  27,      Response:  <Response [200]>
# Year:  2021,      Page:  28,      Response:  <Response [200]>
# Year:  2021,      Page:  29,      Response:  <Response [200]>
# Year:  2021,      Page:  30,      Response:  <Response [200]>
# Year:  2021,      Page:  31,      Response:  <Response [200]>
# Year:  2021,      Page:  32,      Response:  <Response [200]>
# Year:  2021,      Page:  33,      Response:  <Response [200]>
# Year:  2021,      Page:  34,      Response:  <Response [200]>
# Year:  2021,      Page:  35,      Response:  <Response [200]>
# Found total 339 results for year 2021 across 34 pages
# Moving on to year 2022
# ---------------------------------
# Year:  2022,      Page:  1,      Response:  <Response [200]>
# Year:  2022,      Page:  2,      Response:  <Response [200]>
# Year:  2022,      Page:  3,      Response:  <Response [200]>
# Year:  2022,      Page:  4,      Response:  <Response [200]>
# Year:  2022,      Page:  5,      Response:  <Response [200]>
# Year:  2022,      Page:  6,      Response:  <Response [200]>
# Year:  2022,      Page:  7,      Response:  <Response [200]>
# Year:  2022,      Page:  8,      Response:  <Response [200]>
# Year:  2022,      Page:  9,      Response:  <Response [200]>
# Year:  2022,      Page:  10,      Response:  <Response [200]>
# Year:  2022,      Page:  11,      Response:  <Response [200]>
# Year:  2022,      Page:  12,      Response:  <Response [200]>
# Year:  2022,      Page:  13,      Response:  <Response [200]>
# Year:  2022,      Page:  14,      Response:  <Response [200]>
# Year:  2022,      Page:  15,      Response:  <Response [200]>
# Year:  2022,      Page:  16,      Response:  <Response [200]>
# Year:  2022,      Page:  17,      Response:  <Response [200]>
# Year:  2022,      Page:  18,      Response:  <Response [200]>
# Year:  2022,      Page:  19,      Response:  <Response [200]>
# Year:  2022,      Page:  20,      Response:  <Response [200]>
# Year:  2022,      Page:  21,      Response:  <Response [200]>
# Year:  2022,      Page:  22,      Response:  <Response [200]>
# Year:  2022,      Page:  23,      Response:  <Response [200]>
# Year:  2022,      Page:  24,      Response:  <Response [200]>
# Year:  2022,      Page:  25,      Response:  <Response [200]>
# Year:  2022,      Page:  26,      Response:  <Response [200]>
# Year:  2022,      Page:  27,      Response:  <Response [200]>
# Year:  2022,      Page:  28,      Response:  <Response [200]>
# Year:  2022,      Page:  29,      Response:  <Response [200]>
# Year:  2022,      Page:  30,      Response:  <Response [200]>
# Found total 289 results for year 2022 across 29 pages
# Moving on to year 2023
# ---------------------------------
# Year:  2023,      Page:  1,      Response:  <Response [200]>
# Year:  2023,      Page:  2,      Response:  <Response [200]>
# Year:  2023,      Page:  3,      Response:  <Response [200]>
# Year:  2023,      Page:  4,      Response:  <Response [200]>
# Year:  2023,      Page:  5,      Response:  <Response [200]>
# Year:  2023,      Page:  6,      Response:  <Response [200]>
# Year:  2023,      Page:  7,      Response:  <Response [200]>
# Year:  2023,      Page:  8,      Response:  <Response [200]>
# Year:  2023,      Page:  9,      Response:  <Response [200]>
# Year:  2023,      Page:  10,      Response:  <Response [200]>
# Year:  2023,      Page:  11,      Response:  <Response [200]>
# Year:  2023,      Page:  12,      Response:  <Response [200]>
# Year:  2023,      Page:  13,      Response:  <Response [200]>
# Year:  2023,      Page:  14,      Response:  <Response [200]>
# Year:  2023,      Page:  15,      Response:  <Response [200]>
# Year:  2023,      Page:  16,      Response:  <Response [200]>
# Year:  2023,      Page:  17,      Response:  <Response [200]>
# Year:  2023,      Page:  18,      Response:  <Response [200]>
# Year:  2023,      Page:  19,      Response:  <Response [200]>
# Year:  2023,      Page:  20,      Response:  <Response [200]>
# Year:  2023,      Page:  21,      Response:  <Response [200]>
# Year:  2023,      Page:  22,      Response:  <Response [200]>
# Found total 201 results for year 2023 across 21 pages
# XC40 search done.

# %%
astra = get_cars(
    make = "Vauxhall",
    model = "Astra",
    postcode = criteria["postcode"],
    radius = criteria["radius"],
    min_year = criteria["min_year"],
    max_year = criteria["max_year"],
    include_writeoff = "exclude",
    max_attempts_per_page = criteria["max_attempts_per_page"],
    verbose = criteria["verbose"]
)

print("Astra search done.")
# Out:
# Year:  2020,      Page:  1,      Response:  <Response [200]>
# Year:  2020,      Page:  2,      Response:  <Response [200]>
# Year:  2020,      Page:  3,      Response:  <Response [200]>
# Year:  2020,      Page:  4,      Response:  <Response [200]>
# Year:  2020,      Page:  5,      Response:  <Response [200]>
# Year:  2020,      Page:  6,      Response:  <Response [200]>
# Year:  2020,      Page:  7,      Response:  <Response [200]>
# Year:  2020,      Page:  8,      Response:  <Response [200]>
# Year:  2020,      Page:  9,      Response:  <Response [200]>
# Year:  2020,      Page:  10,      Response:  <Response [200]>
# Year:  2020,      Page:  11,      Response:  <Response [200]>
# Year:  2020,      Page:  12,      Response:  <Response [200]>
# Year:  2020,      Page:  13,      Response:  <Response [200]>
# Year:  2020,      Page:  14,      Response:  <Response [200]>
# Year:  2020,      Page:  15,      Response:  <Response [200]>
# Found total 139 results for year 2020 across 14 pages
# Moving on to year 2021
# ---------------------------------
# Year:  2021,      Page:  1,      Response:  <Response [200]>
# Year:  2021,      Page:  2,      Response:  <Response [200]>
# Year:  2021,      Page:  3,      Response:  <Response [200]>
# Year:  2021,      Page:  4,      Response:  <Response [200]>
# Year:  2021,      Page:  5,      Response:  <Response [200]>
# Year:  2021,      Page:  6,      Response:  <Response [200]>
# Found total 50 results for year 2021 across 5 pages
# Moving on to year 2022
# ---------------------------------
# Year:  2022,      Page:  1,      Response:  <Response [200]>
# Year:  2022,      Page:  2,      Response:  <Response [200]>
# Year:  2022,      Page:  3,      Response:  <Response [200]>
# Year:  2022,      Page:  4,      Response:  <Response [200]>
# Year:  2022,      Page:  5,      Response:  <Response [200]>
# Year:  2022,      Page:  6,      Response:  <Response [200]>
# Year:  2022,      Page:  7,      Response:  <Response [200]>
# Year:  2022,      Page:  8,      Response:  <Response [200]>
# Found total 63 results for year 2022 across 7 pages
# Moving on to year 2023
# ---------------------------------
# Year:  2023,      Page:  1,      Response:  <Response [200]>
# Year:  2023,      Page:  2,      Response:  <Response [200]>
# Year:  2023,      Page:  3,      Response:  <Response [200]>
# Year:  2023,      Page:  4,      Response:  <Response [200]>
# Year:  2023,      Page:  5,      Response:  <Response [200]>
# Found total 34 results for year 2023 across 4 pages
# Astra search done.

# %%
ID4 = get_cars(
    make = "Volkswagen",
    model = "ID.4",
    postcode = criteria["postcode"],
    radius = criteria["radius"],
    min_year = criteria["min_year"],
    max_year = criteria["max_year"],
    include_writeoff = "exclude",
    max_attempts_per_page = criteria["max_attempts_per_page"],
    verbose = criteria["verbose"]
)

print("ID.4 search done.")
# Out:
# Year:  2020,      Page:  1,      Response:  <Response [200]>
# Found total 0 results for year 2020 across 0 pages
# Moving on to year 2021
# ---------------------------------
# Year:  2021,      Page:  1,      Response:  <Response [200]>
# Year:  2021,      Page:  2,      Response:  <Response [200]>
# Year:  2021,      Page:  3,      Response:  <Response [200]>
# Year:  2021,      Page:  4,      Response:  <Response [200]>
# Year:  2021,      Page:  5,      Response:  <Response [200]>
# Year:  2021,      Page:  6,      Response:  <Response [200]>
# Year:  2021,      Page:  7,      Response:  <Response [200]>
# Found total 54 results for year 2021 across 6 pages
# Moving on to year 2022
# ---------------------------------
# Year:  2022,      Page:  1,      Response:  <Response [200]>
# Year:  2022,      Page:  2,      Response:  <Response [200]>
# Year:  2022,      Page:  3,      Response:  <Response [200]>
# Year:  2022,      Page:  4,      Response:  <Response [200]>
# Year:  2022,      Page:  5,      Response:  <Response [200]>
# Year:  2022,      Page:  6,      Response:  <Response [200]>
# Year:  2022,      Page:  7,      Response:  <Response [200]>
# Year:  2022,      Page:  8,      Response:  <Response [200]>
# Year:  2022,      Page:  9,      Response:  <Response [200]>
# Year:  2022,      Page:  10,      Response:  <Response [200]>
# Year:  2022,      Page:  11,      Response:  <Response [200]>
# Found total 91 results for year 2022 across 10 pages
# Moving on to year 2023
# ---------------------------------
# Year:  2023,      Page:  1,      Response:  <Response [200]>
# Year:  2023,      Page:  2,      Response:  <Response [200]>
# Year:  2023,      Page:  3,      Response:  <Response [200]>
# Year:  2023,      Page:  4,      Response:  <Response [200]>
# Year:  2023,      Page:  5,      Response:  <Response [200]>
# Year:  2023,      Page:  6,      Response:  <Response [200]>
# Year:  2023,      Page:  7,      Response:  <Response [200]>
# Year:  2023,      Page:  8,      Response:  <Response [200]>
# Year:  2023,      Page:  9,      Response:  <Response [200]>
# Found total 72 results for year 2023 across 8 pages
# ID.4 search done.

# %%
ID5 = get_cars(
    make = "Volkswagen",
    model = "ID.5",
    postcode = criteria["postcode"],
    radius = criteria["radius"],
    min_year = criteria["min_year"],
    max_year = criteria["max_year"],
    include_writeoff = "exclude",
    max_attempts_per_page = criteria["max_attempts_per_page"],
    verbose = criteria["verbose"]
)

print("ID.5 search done.")
# Out:
# Year:  2020,      Page:  1,      Response:  <Response [200]>
# Found total 0 results for year 2020 across 0 pages
# Moving on to year 2021
# ---------------------------------
# Year:  2021,      Page:  1,      Response:  <Response [200]>
# Found total 0 results for year 2021 across 0 pages
# Moving on to year 2022
# ---------------------------------
# Year:  2022,      Page:  1,      Response:  <Response [200]>
# Year:  2022,      Page:  2,      Response:  <Response [200]>
# Year:  2022,      Page:  3,      Response:  <Response [200]>
# Year:  2022,      Page:  4,      Response:  <Response [200]>
# Year:  2022,      Page:  5,      Response:  <Response [200]>
# Year:  2022,      Page:  6,      Response:  <Response [200]>
# Year:  2022,      Page:  7,      Response:  <Response [200]>
# Year:  2022,      Page:  8,      Response:  <Response [200]>
# Year:  2022,      Page:  9,      Response:  <Response [200]>
# Year:  2022,      Page:  10,      Response:  <Response [200]>
# Year:  2022,      Page:  11,      Response:  <Response [200]>
# Year:  2022,      Page:  12,      Response:  <Response [200]>
# Year:  2022,      Page:  13,      Response:  <Response [200]>
# Year:  2022,      Page:  14,      Response:  <Response [200]>
# Year:  2022,      Page:  15,      Response:  <Response [200]>
# Year:  2022,      Page:  16,      Response:  <Response [200]>
# Year:  2022,      Page:  17,      Response:  <Response [200]>
# Year:  2022,      Page:  18,      Response:  <Response [200]>
# Year:  2022,      Page:  19,      Response:  <Response [200]>
# Year:  2022,      Page:  20,      Response:  <Response [200]>
# Found total 190 results for year 2022 across 19 pages
# Moving on to year 2023
# ---------------------------------
# Year:  2023,      Page:  1,      Response:  <Response [200]>
# Year:  2023,      Page:  2,      Response:  <Response [200]>
# Year:  2023,      Page:  3,      Response:  <Response [200]>
# Year:  2023,      Page:  4,      Response:  <Response [200]>
# Year:  2023,      Page:  5,      Response:  <Response [200]>
# Found total 37 results for year 2023 across 4 pages
# ID.5 search done.

# %%
"make" + " " + "model"

# %%
ioniq[10]

# %%
results = (
    prius + 
    corolla + 
    ioniq +
    ioniq_5 +
    civic +
    niro +
    EV6 +
    XC40 +
    astra +
    ID4 +
    ID5    
)

print(f"Found {len(results)} total results.")

df = pd.DataFrame.from_records(results)

df["price"] = df["price"] \
    .str.replace("£", "") \
    .str.replace(",", "") \
    .astype(int)

df["distance"] = df["seller"].str.extract(r'(\d+ mile)', expand=False)
df["distance"] = df["distance"].str.replace(" mile", "")
df["distance"] = pd.to_numeric(df["distance"], errors="coerce").astype("Int64")

df["year"] = df["year"].str.replace(r"\s(\(\d\d reg\))", "", regex=True)
df["year"] = pd.to_numeric(df["year"], errors="coerce").astype("Int64")

print(f"{len(df)} cars met the criteria. Saving to 'autotrader-df.csv'")

df2 = df.sort_values(by="distance")
df2.to_csv("autotrader-df.csv")
# Out:
# Found 4955 total results.
# 4955 cars met the criteria. Saving to 'autotrader-df.csv'

# %%
shortlist = df[
  (df["price"] >= criteria["min_price"]) & 
  (df["price"] <= criteria["max_price"]) &
  (df["fuel"] == criteria["fuel"]) &
  (df["mileage"] <= criteria["max_mileage"]) &
  (df["transmission"] == criteria["transmission"]) &
  (df["engine"] != "1.0L") &
  (df["engine"] != "1.2L")
]

print(f"{len(shortlist)} cars met the criteria. Saving to 'autotrader-shortlist.csv'")

shortlist = shortlist.sort_values(by="distance")
shortlist.to_csv("autotrader-shortlist.csv")

# %% [markdown]
# # Manually adaptig the script to scrape additional info from the url

# %%
import cloudscraper
import requests
from bs4 import BeautifulSoup
url = 'https://www.autotrader.co.uk/car-details/202303165299047'
# url = 'https://www.autotrader.co.uk/car-search?journey=YOU_MAY_ALSO_LIKE_JOURNEY&advertising-location=at_cars&fuel-type=Electric&include-delivery-option=on&make=Hyundai&model=IONIQ&postcode=LS6%203DT&sort=price-asc&year-from=2020&year-to=2020&flrfc=1#202302164339789'

url = 'https://www.autotrader.co.uk/car-details/202303165299047'
scraper = cloudscraper.create_scraper()
response = scraper.get(url)

article = response.content

# %%
article

# %%
article_decode = response.content.decode('utf-8')

# %%
article_decode

# %%
import cloudscraper
from bs4 import BeautifulSoup

url = 'https://www.autotrader.co.uk/car-details/202303165299047'
scraper = cloudscraper.create_scraper()
response = scraper.get(url)
html_content = response.content.decode('utf-8')

soup = BeautifulSoup(html_content, 'html.parser')
title_element = soup.find("h3", {"class": "product-card-details__title"})

if title_element:
    title_text = title_element.get_text()
    print(title_text)
else:
    print("Title element not found")

# %%
soup

# %%
article_decode.find("h3", {"class": "product-card-details__title"})

# %%
article.find("h3", {"class": "product-card-details__title"}).text.strip()

# %%
car = {}
car["model"] = make + " " + model
car["name"] = article.find("h3", {"class": "product-card-details__title"}).text.strip()             
car["link"] = "https://www.autotrader.co.uk" + \
      article.find("a", {"class": "listing-fpa-link"})["href"][: article.find("a", {"class": "listing-fpa-link"})["href"] \
      .find("?")]
car["price"] = article.find("div", {"class": "product-card-pricing__price"}).text.strip()

seller_info = article.find("ul", {"class": "product-card-seller-info__specs"}).text.strip()
car["seller"] = " ".join(seller_info.split())

key_specs_bs_list = article.find("ul", {"class": "listing-key-specs"}).find_all("li")

for key_spec_bs_li in key_specs_bs_list:

    key_spec_bs = key_spec_bs_li.text

    if any(keyword in key_spec_bs for keyword in keywords["mileage"]):
        car["mileage"] = int(key_spec_bs[:key_spec_bs.find(" miles")].replace(",",""))
    elif any(keyword in key_spec_bs for keyword in keywords["BHP"]):
        car["BHP"] = int(key_spec_bs[:key_spec_bs.find("BHP")])
    elif any(keyword in key_spec_bs for keyword in keywords["transmission"]):
        car["transmission"] = key_spec_bs
    elif any(keyword in key_spec_bs for keyword in keywords["fuel"]):
        car["fuel"] = key_spec_bs
    elif any(keyword in key_spec_bs for keyword in keywords["owners"]):
        car["owners"] = int(key_spec_bs[:key_spec_bs.find(" owners")])
    elif any(keyword in key_spec_bs for keyword in keywords["body"]):
        car["body"] = key_spec_bs
    elif any(keyword in key_spec_bs for keyword in keywords["ULEZ"]):
        car["ULEZ"] = key_spec_bs
    elif any(keyword in key_spec_bs for keyword in keywords["year"]):
        car["year"] = key_spec_bs
    elif key_spec_bs[1] == "." and key_spec_bs[3] == "L":
        car["engine"] = key_spec_bs
